# %%
#   Libraries

import numpy
import sklearn
import cv2 as cv
import albumentations as A
import torch
import pycocotools
import matplotlib
import pandas as pd
import opencv

# %%
#   Paths

c_path = 'data/coco_dataset/'
p_i_path = 'data/product_images'

# %%
#   load dataset

# import data here
